# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.xlabel('area')
plt.ylabel('price')
plt.scatter(df.area,df.price,color='red',marker="*")

# %%
new_df = df.drop('price',axis ='columns')
new_df
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
model = linear_model.LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(new_df,df.price)
# Out:
# LinearRegression()

# %%
model.predict([[5000]])
# Out:
# C:\Users\shrey\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
# !pip install pandas numpy scikit-learn matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ---------------------------------------- 60.8/60.8 kB 1.1 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------------------------------- 165.5/165.5 kB 5.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/10.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/10.9 MB 12.2 MB/s eta 0:00:01
#    -- ------------------------------------- 0.8/10.9 MB 8.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.0/10.9 MB 6.7 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.1/10.9 MB 6.0 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.3/10.9 MB 5.6 MB/s eta 0:00:02
# ...

# %%
model.intercept_
# Out:
# np.float64(180616.43835616432)

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ---------------------------------------- 60.9/60.9 kB 1.1 MB/s eta 0:00:00
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.2/11.5 MB 7.6 MB/s eta 0:00:02
#    -- ------------------------------------- 0.7/11.5 MB 8.9 MB/s eta 0:00:02
#    --- ------------------------------------ 0.9/11.5 MB 7.0 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.5 MB 6.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.5 MB 6.1 MB/s eta 0:00:02
#    --- ------------------------------------ 1.1/11.5 MB 6.1 MB/s eta 0:00:02
# ...

# %%
new_dff = pd.read_csv('areas.csv')
new_dff
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = model.predict(new_dff)

# %%
new_dff.to_csv('prediction.csv')

# %%
country = pd.read_csv("canada_per_capita_income.csv")
country
# Out:
#     year  per capita income (US$)
# 0   1970              3399.299037
# 1   1971              3768.297935
# 2   1972              4251.175484
# 3   1973              4804.463248
# 4   1974              5576.514583
# 5   1975              5998.144346
# 6   1976              7062.131392
# 7   1977              7100.126170
# 8   1978              7247.967035
# 9   1979              7602.912681
# 10  1980              8355.968120
# 11  1981              9434.390652
# 12  1982              9619.438377
# 13  1983             10416.536590
# 14  1984             10790.328720
# 15  1985             11018.955850
# 16  1986             11482.891530
# 17  1987             12974.806620
# 18  1988             15080.283450
# 19  1989             16426.725480
# 20  1990             16838.673200
# 21  1991             17266.097690
# 22  1992             16412.083090
# 23  1993             15875.586730
# 24  1994             15755.820270
# 25  1995             16369.317250
# ...

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('Per Capita Income (US$)')
plt.scatter(country['year'], country['per capita income (US$)'], color="red", marker="*")

# %%
new = country.drop('year',axis = 1)
new
# Out:
#     per capita income (US$)
# 0               3399.299037
# 1               3768.297935
# 2               4251.175484
# 3               4804.463248
# 4               5576.514583
# 5               5998.144346
# 6               7062.131392
# 7               7100.126170
# 8               7247.967035
# 9               7602.912681
# 10              8355.968120
# 11              9434.390652
# 12              9619.438377
# 13             10416.536590
# 14             10790.328720
# 15             11018.955850
# 16             11482.891530
# 17             12974.806620
# 18             15080.283450
# 19             16426.725480
# 20             16838.673200
# 21             17266.097690
# 22             16412.083090
# 23             15875.586730
# 24             15755.820270
# 25             16369.317250
# 26             16699.826680
# 27             17310.757750
# 28             16622.671870
# 29             17581.024140
# 30             18987.382410
# 31             18601.397240
# ...

# %%
model_3 = linear_model.LinearRegression()

# %%
X = country[['year']]  
y = country['per capita income (US$)']

# %%
model_3 = linear_model.LinearRegression()
model_3.fit(X, y)
# Out:
# LinearRegression()

# %%
year_to_predict = [[2018]]
predicted_income = model_3.predict(year_to_predict)
print(f"Predicted per capita income for {year_to_predict[0][0]}: ${predicted_income[0]:.2f}")
# Out:
# Predicted per capita income for 2018: $39631.76
# C:\Users\shrey\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(country['year'], country['per capita income (US$)'], color="red", marker="*")
plt.plot(country['year'], model_3.predict(X), color="blue")
plt.xlabel('Year')
plt.ylabel('Per Capita Income (US$)')
plt.show()
